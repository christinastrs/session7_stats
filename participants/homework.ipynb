# %% [markdown]
# <font color='pink'>**Homework exercise**</font>
#
# This is our final session. After today, you know how to work with Python on your own laptop, to work with GIT for code organisation (and version control), to use Python's built-in data types, functions and modules to solve tasks like renaming files or generating random lists of experimental stimuli. On top of all that, you know how to use external packages (and more importantly to solve weird annoying errors installing external packages), program a simple experiment and how to import, process and analyze experimental data.
#
# Now let's put that into practice! For this final homework assignment we like you to read in a dataset of choice. We ask you to create an analysis-notebook, that should contain at least:
#
# - A nice introduction at the top, explaining what you did (in a Markdown cell)
# - A table summarizing your data
# - A plot of your contrast of interest
# - A statistical test to determine its significance
# - In between: text boxes in markdown describing what you are doing
#
# We like you to do this in a completely new, fresh notebook.
#
#
# Here we'd also like to thank you for your great efforts (and for not getting mad when we encountered so many installation errors). We really had a great time and hope you learned something useful :) .

# %% [markdown]
# Hello! First of all, I would like to thank you for this lovely and insightful course! I learned a lot from you and I hope to implement them in my future reseach! Dank jullie wel!
#
# For this homework, I used the dataset from my thesis. THere [explain the variables and what you measured]

# %%
#import packages

import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import math
import statistics
import numpy as np
import pandas as pd
import os

# %%
path = 'C://Users/Christina Papoutsi/IMPRS-Python-course-session1/session7_stats/'

# load the data we used previously
trials = pd.read_csv(os.path.join(path, 'all_data2_21.csv'))
trials
# Out:
#                File  sbj  Block_nr  Trial_nr  ItemID      word_1  \
# 0      Exp_EEG2.txt    2         1         1     177        pijp
# 1      Exp_EEG2.txt    2         1         2     191     gangpad
# 2      Exp_EEG2.txt    2         1         3     157     groente
# 3      Exp_EEG2.txt    2         1         4      59       sloeg
# 4      Exp_EEG2.txt    2         1         5     160      piloot
# ...             ...  ...       ...       ...     ...         ...
# 4395  Exp_EEG21.txt   21        10       216     159  strijkstok
# 4396  Exp_EEG21.txt   21        10       217     196      dooier
# 4397  Exp_EEG21.txt   21        10       218     202         wol
# 4398  Exp_EEG21.txt   21        10       219      29   astronaut
# 4399  Exp_EEG21.txt   21        10       220     134     beltoon
#
#              word_2      word_3    picture      filename  marker  \
# 0       lauwerkrans       farao      clown     clown.png       7
# 1          zoomlens  bladmuziek    octopus   octopus.png       7
# 2          knoflook      sjalot         ui     onion.png       3
# 3         kakkerlak         met      bezem   broom01.png       9
# 4        helikopter  stewardess  vliegtuig     plane.png       3
# ...             ...         ...        ...           ...     ...
# 4395            kin       snaar      viool    violin.png       3
# 4396  ruimtestation        foto    plantje  plant02b.png       7
# 4397          larve        pink     schoen      shoe.png       7
# 4398         landde          op       maan      moon.png       1
# 4399   tekstbericht    batterij  mobieltje    mobile.png       3
#
#          condition constraint wordorder  presentation_RT  accuracy  \
# 0     unstructured         uc        NO              859         1
# 1     unstructured         uc        NO                0         1
# 2     unstructured          c        NO              600         1
# 3       structured         uc       VOP                0         1
# 4     unstructured          c        NO                0         1
# ...            ...        ...       ...              ...       ...
# 4395  unstructured          c        NO              749         1
# 4396  unstructured         uc        NO              739         1
# 4397  unstructured         uc        NO              559         1
# 4398    structured          c       SVP              840         1
# 4399  unstructured          c        NO              910         1
#
#      accuracy_comments  manual_RT
# 0                  NaN   0.800000
# 1                  NaN   0.693333
# 2                  NaN   0.528863
# 3                  NaN   0.680000
# 4                  NaN   0.631601
# ...                ...        ...
# 4395               NaN   0.773333
# 4396               NaN   0.773333
# 4397               NaN   0.545419
# 4398               NaN   0.826667
# 4399               NaN   0.906667
#
# [4400 rows x 18 columns]

# %%
summary = trials.groupby(by=['condition', 'constraint']).aggregate(
    mean_RT=pd.NamedAgg('manual_RT', np.mean),
    median_RT=pd.NamedAgg('manual_RT', np.median),
    std_RT=pd.NamedAgg('manual_RT', np.std)
)

summary
# Out:
#                           mean_RT  median_RT    std_RT
# condition    constraint
# structured   c           0.571556   0.551469  0.193488
#              uc          0.732012   0.687108  0.207592
# unstructured c           0.610141   0.592709  0.220743
#              uc          0.718179   0.686166  0.181287

# %%
summary.reset_index(inplace=True)
summary
# Out:
#       condition constraint   mean_RT  median_RT    std_RT
# 0    structured          c  0.571556   0.551469  0.193488
# 1    structured         uc  0.732012   0.687108  0.207592
# 2  unstructured          c  0.610141   0.592709  0.220743
# 3  unstructured         uc  0.718179   0.686166  0.181287

# %%
# sns.boxplot(x=['condition', 'constraint'], y='manual_RT', data=trials)
sns.boxplot(x='constraint', y='manual_RT', data=trials, hue="condition")

plt.show()

# %%
import statsmodels.formula.api as smf

lmm0 = smf.mixedlm("manual_RT ~ condition * constraint", trials, groups = [trials['sbj'],trials['ItemID']], re_formula='1')
lmm0f = lmm0.fit()
print(lmm0f.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Christina Papoutsi\IMPRS-Python-course-session1\session7_stats\participants\homework.ipynb Cell 8' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Christina%20Papoutsi/IMPRS-Python-course-session1/session7_stats/participants/homework.ipynb#ch0000009?line=0'>1</a> import statsmodels.formula.api as smf
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Christina%20Papoutsi/IMPRS-Python-course-session1/session7_stats/participants/homework.ipynb#ch0000009?line=2'>3</a> lmm0 = smf.mixedlm("manual_RT ~ condition * constraint", trials, groups = [trials['sbj'],trials['ItemID']], re_formula='1')
#       <a href='vscode-notebook-cell:/c%3A/Users/Christina%20Papoutsi/IMPRS-Python-course-session1/session7_stats/participants/homework.ipynb#ch0000009?line=3'>4</a> lmm0f = lmm0.fit()
#       <a href='vscode-notebook-cell:/c%3A/Users/Christina%20Papoutsi/IMPRS-Python-course-session1/session7_stats/participants/homework.ipynb#ch0000009?line=4'>5</a> print(lmm0f.summary())
#
# File c:\Python39\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1046, in MixedLM.from_formula(cls, formula, data, re_formula, vc_formula, subset, use_sparse, missing, *args, **kwargs)
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1043'>1044</a> kwargs["exog_vc"] = exog_vc
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1044'>1045</a> kwargs["groups"] = groups
# -> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1045'>1046</a> mod = super(MixedLM, cls).from_formula(
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1046'>1047</a>     formula, data, *args, **kwargs)
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1048'>1049</a> # expand re names to account for pairs of RE
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1049'>1050</a> (param_names,
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1050'>1051</a>  exog_re_names,
#    <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=1051'>1052</a>  exog_re_names_full) = mod._make_param_names(exog_re_names)
#
# File c:\Python39\lib\site-packages\statsmodels\base\model.py:226, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=219'>220</a>         design_info = design_info.subset(cols)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=221'>222</a> kwargs.update({'missing_idx': missing_idx,
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=222'>223</a>                'missing': missing,
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=223'>224</a>                'formula': formula,  # attach formula for unpckling
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=224'>225</a>                'design_info': design_info})
# --> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=225'>226</a> mod = cls(endog, exog, *args, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=226'>227</a> mod.formula = formula
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=227'>228</a> # since we got a dataframe, attach the original
#
# File c:\Python39\lib\site-packages\statsmodels\regression\mixed_linear_model.py:741, in MixedLM.__init__(self, endog, exog, groups, exog_re, exog_vc, use_sqrt, missing, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=736'>737</a>     exog_re = exog_re[:, None]
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=738'>739</a> # Calling super creates self.endog, etc. as ndarrays and the
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=739'>740</a> # original exog, endog, etc. are self.data.endog, etc.
# --> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=740'>741</a> super(MixedLM, self).__init__(endog, exog, groups=groups,
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=741'>742</a>                               exog_re=exog_re, missing=missing,
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=742'>743</a>                               **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=744'>745</a> self._init_keys.extend(["use_sqrt", "exog_vc"])
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/regression/mixed_linear_model.py?line=746'>747</a> # Number of fixed effects parameters
#
# File c:\Python39\lib\site-packages\statsmodels\base\model.py:267, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=265'>266</a> def __init__(self, endog, exog=None, **kwargs):
# --> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=266'>267</a>     super().__init__(endog, exog, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=267'>268</a>     self.initialize()
#
# File c:\Python39\lib\site-packages\statsmodels\base\model.py:92, in Model.__init__(self, endog, exog, **kwargs)
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=89'>90</a> missing = kwargs.pop('missing', 'none')
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=90'>91</a> hasconst = kwargs.pop('hasconst', None)
# ---> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=91'>92</a> self.data = self._handle_data(endog, exog, missing, hasconst,
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=92'>93</a>                               **kwargs)
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=93'>94</a> self.k_constant = self.data.k_constant
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=94'>95</a> self.exog = self.data.exog
#
# File c:\Python39\lib\site-packages\statsmodels\base\model.py:132, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=130'>131</a> def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=131'>132</a>     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=132'>133</a>     # kwargs arrays could have changed, easier to just attach here
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/model.py?line=133'>134</a>     for key in kwargs:
#
# File c:\Python39\lib\site-packages\statsmodels\base\data.py:673, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=669'>670</a>     exog = np.asarray(exog)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=671'>672</a> klass = handle_data_class_factory(endog, exog)
# --> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=672'>673</a> return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=673'>674</a>              **kwargs)
#
# File c:\Python39\lib\site-packages\statsmodels\base\data.py:70, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=67'>68</a>     self.formula = kwargs.pop('formula')
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=68'>69</a> if missing != 'none':
# ---> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=69'>70</a>     arrays, nan_idx = self.handle_missing(endog, exog, missing,
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=70'>71</a>                                           **kwargs)
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=71'>72</a>     self.missing_row_idx = nan_idx
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=72'>73</a>     self.__dict__.update(arrays)  # attach all the data arrays
#
# File c:\Python39\lib\site-packages\statsmodels\base\data.py:266, in ModelData.handle_missing(cls, endog, exog, missing, **kwargs)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=263'>264</a>     nan_mask = _nan_rows(*combined)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=264'>265</a>     if combined_2d:
# --> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=265'>266</a>         nan_mask = _nan_rows(*(nan_mask[:, None],) + combined_2d)
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=267'>268</a> if not np.any(nan_mask):  # no missing do not do anything
#     <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=268'>269</a>     combined = dict(zip(combined_names, combined))
#
# File c:\Python39\lib\site-packages\statsmodels\base\data.py:49, in _nan_rows(*arrs)
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=45'>46</a>     x_is_boolean_array = hasattr(x, 'dtype') and x.dtype == bool and x
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=46'>47</a>     return np.logical_or(_asarray_2d_null_rows(x),
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=47'>48</a>                          (x_is_boolean_array | _asarray_2d_null_rows(y)))
# ---> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=48'>49</a> return reduce(_nan_row_maybe_two_inputs, arrs).squeeze()
#
# File c:\Python39\lib\site-packages\statsmodels\base\data.py:48, in _nan_rows.<locals>._nan_row_maybe_two_inputs(x, y)
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=43'>44</a> def _nan_row_maybe_two_inputs(x, y):
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=44'>45</a>     # check for dtype bc dataframe has dtypes
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=45'>46</a>     x_is_boolean_array = hasattr(x, 'dtype') and x.dtype == bool and x
#      <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=46'>47</a>     return np.logical_or(_asarray_2d_null_rows(x),
# ---> <a href='file:///c%3A/Python39/lib/site-packages/statsmodels/base/data.py?line=47'>48</a>                          (x_is_boolean_array | _asarray_2d_null_rows(y)))
#
# ValueError: operands could not be broadcast together with shapes (4400,1) (2,1)
